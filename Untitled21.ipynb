# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumya164/Wiki-Ceawler/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scrapy
from scrapy.crawler import CrawlerProcess
import pandas as pd

# %%
! pip install scrapy
# Out:
# ...
#      |████████████████████████████████| 264 kB 27.5 MB/s
# ...
#      |████████████████████████████████| 55 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 47 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 3.6 MB 51.8 MB/s
# ...
#      |████████████████████████████████| 87 kB 5.8 MB/s
# ...
#      |████████████████████████████████| 251 kB 66.7 MB/s
# ...
#      |████████████████████████████████| 3.1 MB 62.7 MB/s
# ...
#      |████████████████████████████████| 74 kB 3.5 MB/s
# ...
#   Created wheel for PyDispatcher: filename=PyDispatcher-2.0.5-py3-none-any.whl size=11516 sha256=88092ba11a86e274b4381d14b9ae164d4ac337d827a8d8c5e333ea2ac8b87d28
#   Stored in directory: /root/.cache/pip/wheels/2d/18/21/3c6a732eaa69a339198e08bb63b7da2c45933a3428b29ec454
# Successfully built PyDispatcher
# ...

# %%
table = {
    'Title': [],
    'URL': [],
    'Budget': []
}

# %%
class MoviesSpider(scrapy.Spider):
    name = 'spiderman'
    start_urls = [
        'https://en.wikipedia.org/wiki/Academy_Award_for_Best_Picture']

    def parse(self, response):
        url_path = '//tr[@style="background:#FAEB86"]/td[1]//a/@href'
        title_path = '//tr[@style="background:#FAEB86"]/td[1]//a/@title'

        movies = response.xpath(url_path).getall()
        titles = response.xpath(title_path).getall()

        for movie in movies:
            table.get('URL').append("https://en.wikipedia.org/"+movie)
        for title in titles:
            table.get('Title').append(title)

        for link in table.get('URL'):
            yield scrapy.Request(url=link, callback=self.parse2)

    def parse2(self, response):
        budget_path = '//th[contains(text(), "Budget")]/following-sibling::td/text()'
        budget = response.xpath(budget_path).get()
        if not budget:
            budget = 'Unavailable'
        table['Budget'].append(budget)

# %%
process = CrawlerProcess()
process.crawl(MoviesSpider)
process.start()
# Out:
# 2022-03-02 04:09:52 [scrapy.utils.log] INFO: Scrapy 2.6.1 started (bot: scrapybot)
# 2022-03-02 04:09:52 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.1.0, Python 3.7.12 (default, Jan 15 2022, 18:48:18) - [GCC 7.5.0], pyOpenSSL 22.0.0 (OpenSSL 1.1.1m  14 Dec 2021), cryptography 36.0.1, Platform Linux-5.4.144+-x86_64-with-Ubuntu-18.04-bionic
# 2022-03-02 04:09:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2022-03-02 04:09:52 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2022-03-02 04:09:52 [scrapy.extensions.telnet] INFO: Telnet Password: 6306bab74228ae53
# 2022-03-02 04:09:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
df = pd.DataFrame(table)
df
# Out:
#                                             Title  ...                                              Budget
# 0                               Wings (1927 film)  ...  US$ 2 million ($28,850,173 adjusted for inflation)
# 1                             The Broadway Melody  ...                                         $17 million
# 2      All Quiet on the Western Front (1930 film)  ...                               $1 million (£467,000)
# 3                            Cimarron (1931 film)  ...                                       $12.6 million
# 4                         Grand Hotel (1932 film)  ...                                          $2 million
# 5                           Cavalcade (1933 film)  ...                                         $10 million
# 6                           It Happened One Night  ...                                        $3.2 million
# 7                Mutiny on the Bounty (1935 film)  ...                                          $2 million
# ...
